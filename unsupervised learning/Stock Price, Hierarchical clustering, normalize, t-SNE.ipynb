# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import normalize
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.manifold import TSNE

# %% [markdown]
# ## Company Stock Price Movements Dataset

# %%
stocks = pd.read_csv('https://assets.datacamp.com/production/course_2072/datasets/company-stock-movements-2010-2015-incl.csv', 
                 index_col=0)
stocks.head()
# Out:
#                   2010-01-04  2010-01-05  2010-01-06  2010-01-07  2010-01-08  \
# Apple               0.580000   -0.220005   -3.409998   -1.170000    1.680011
# AIG                -0.640002   -0.650000   -0.210001   -0.420000    0.710001
# Amazon             -2.350006    1.260009   -2.350006   -2.009995    2.960006
# American express    0.109997    0.000000    0.260002    0.720002    0.190003
# Boeing              0.459999    1.770000    1.549999    2.690003    0.059997
#
#                   2010-01-11  2010-01-12  2010-01-13  2010-01-14  2010-01-15  \
# Apple              -2.689994   -1.469994    2.779997   -0.680003   -4.999995
# AIG                -0.200001   -1.130001    0.069999   -0.119999   -0.500000
# Amazon             -2.309997   -1.640007    1.209999   -1.790001   -2.039994
# American express   -0.270001    0.750000    0.300004    0.639999   -0.130001
# Boeing             -1.080002    0.360000    0.549999    0.530002   -0.709999
#
# ...

# %%
movements = stocks.values
companies = stocks.index.values
movements.shape, companies.shape
# Out:
# ((60, 963), (60,))

# %% [markdown]
# ## Hierarchical clustering of Stocks

# %%
# SciPy hierarchical clustering doesn't fit into a sklearn pipeline.
# Use the normalize() function instead of Normalizer.
# Normalize the movements
normalized_movements = normalize(movements)

# %%
# Calculate the linkage
mergings = linkage(normalized_movements, method='complete')

# %%
# Plot the dendrogram
plt.figure(figsize=(20,10))
dendrogram(mergings,
           labels=companies,
           leaf_rotation=90,
           leaf_font_size=12)
plt.show()

# %% [markdown]
# ## t-SNE map

# %%
# Create a TSNE instance
model = TSNE(learning_rate=50)

# %%
# Apply fit_transform to normalized_movements
tsne_features = model.fit_transform(normalized_movements)

# %%
# Select features
xs = tsne_features[:,0]
ys = tsne_features[:,1]

# %%
# Scatter plot
plt.figure(figsize=(20,10))
plt.scatter(xs, ys, alpha=0.5)

# Annotate the points
for x, y, company in zip(xs, ys, companies):
    plt.annotate(company, (x, y), fontsize=14, alpha=0.75)

plt.show()
