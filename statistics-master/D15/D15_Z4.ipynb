# %% [markdown]
# # Dickey Fuller Test
# Test Dickey-Fuller: jest to jeden ze statystycznych testów sprawdzających stacjonarność. Tutaj hipoteza zerowa to, że szereg czasowy jest niestacjonarny.
# Wyniki testu obejmują statystykę testu oraz niektóre wartości krytyczne dla różnych poziomów ufności. Jeśli statystyka testowa jest mniejsza niż  wartość krytyczna, możemy odrzucić hipotezę zerową i powiedzieć, że szereg czasowy jest stacjonarny.

# %%
import numpy as np
import pandas as pd
import scipy
import random
import matplotlib.pylab as plt
from statsmodels.tsa.stattools import adfuller

# %%
x = [0]
for j in range(1000):
    x.append(x[j] + np.random.normal())

# %%
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()

# %% [markdown]
# # Zadanie
# proszę wykonać Dickey Fuller test dla powyższych danych.

# %%
dftest = adfuller(df, autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Test Statistic                   -2.249308
# p-value                           0.188838
# #Lags Used                        0.000000
# Number of Observations Used    1000.000000
# Critical Value (1%)              -3.436906
# Critical Value (5%)              -2.864435
# Critical Value (10%)             -2.568311
# dtype: float64

# %% [markdown]
# # rho=0

# %%
rho=0
x = [0]
for j in range(1000):
    x.append(rho*x[j] + np.random.normal())
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()

# %% [markdown]
# # Zadanie
# proszę wykonać Dickey Fuller test dla powyższych danych.

# %%
dftest = adfuller(df, autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Test Statistic                  -31.595166
# p-value                           0.000000
# #Lags Used                        0.000000
# Number of Observations Used    1000.000000
# Critical Value (1%)              -3.436906
# Critical Value (5%)              -2.864435
# Critical Value (10%)             -2.568311
# dtype: float64

# %% [markdown]
# # rho=0.5

# %%
rho=0.5
x = [0]
for j in range(1000):
    x.append(rho*x[j] + np.random.normal())
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()

# %% [markdown]
# # Zadanie
# proszę wykonać Dickey Fuller test dla powyższych danych.

# %%
dftest = adfuller(df, autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Test Statistic                -1.846100e+01
# p-value                        2.146756e-30
# #Lags Used                     0.000000e+00
# Number of Observations Used    1.000000e+03
# Critical Value (1%)           -3.436906e+00
# Critical Value (5%)           -2.864435e+00
# Critical Value (10%)          -2.568311e+00
# dtype: float64

# %% [markdown]
# # rho=0.9

# %%
rho=0.9
x = [0]
for j in range(1000):
    x.append(rho*x[j] + np.random.normal())
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()

# %% [markdown]
# # Zadanie
# proszę wykonać Dickey Fuller test dla powyższych danych.

# %%
dftest = adfuller(df, autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Test Statistic                -7.500277e+00
# p-value                        4.271660e-11
# #Lags Used                     0.000000e+00
# Number of Observations Used    1.000000e+03
# Critical Value (1%)           -3.436906e+00
# Critical Value (5%)           -2.864435e+00
# Critical Value (10%)          -2.568311e+00
# dtype: float64

# %% [markdown]
# # rho=1

# %%
rho=1
x = [0]
for j in range(1000):
    x.append(rho*x[j] + np.random.normal())
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()

# %% [markdown]
# # Zadanie
# proszę wykonać Dickey Fuller test dla powyższych danych.

# %%
dftest = adfuller(df, autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Test Statistic                   -3.417902
# p-value                           0.010364
# #Lags Used                        0.000000
# Number of Observations Used    1000.000000
# Critical Value (1%)              -3.436906
# Critical Value (5%)              -2.864435
# Critical Value (10%)             -2.568311
# dtype: float64
