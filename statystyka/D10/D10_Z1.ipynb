# %% [markdown]
# # Regresja liniowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
M1 = np.vstack( (np.ones_like(x), x) ).T
p1 = np.linalg.lstsq(M1, y)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_1 = lambda x: p1[0][1] * x +p1[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_1(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2) ).T
p2 = np.linalg.lstsq(M2, y)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_2 = lambda x: p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M3 = np.vstack( (np.ones_like(x), x, x**2, x**3) ).T
p3 = np.linalg.lstsq(M3, y)

# %%
f_lr_3 = lambda x: p3[0][3]*pow(x,3) + p3[0][2]*pow(x,2) + p3[0][1] * x + p3[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_3(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M4 = np.vstack( (np.ones_like(x), x, x**2, x**3, x**4) ).T
p4 = np.linalg.lstsq(M4, y)
f_lr_4 = lambda x: p4[0][4]*pow(x,4) + p4[0][3]*pow(x,3) + p4[0][2]*pow(x,2) + p4[0][1] * x + p4[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_4(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M5 = np.vstack( (np.ones_like(x), x, x**2, x**3, x**4, x**5) ).T
p5 = np.linalg.lstsq(M5, y)
f_lr_5 = lambda x: p5[0][5]*pow(x,5) + p5[0][4]*pow(x,4) + p5[0][3]*pow(x,3) + p5[0][2]*pow(x,2) + p5[0][1] * x + p5[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_5(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najleprza?

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
import statsmodels.api as sm
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()
Res3 = sm.OLS(y, M3).fit()
Res4 = sm.OLS(y, M4).fit()
Res5 = sm.OLS(y, M5).fit()

# %%
print(Res1.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res3.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res4.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res5.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.492
# Dependent Variable: y                AIC:                619.2441
# Date:               2017-05-21 10:06 BIC:                624.4545
# No. Observations:   100              Log-Likelihood:     -307.62
# Df Model:           1                F-statistic:        96.93
# Df Residuals:       98               Prob (F-statistic): 2.62e-16
# R-squared:          0.497            Scale:              28.072
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const     -2.8412     1.0477   -2.7119   0.0079   -4.9202   -0.7621
# x1         6.1077     0.6204    9.8455   0.0000    4.8767    7.3388
# -----------------------------------------------------------------
# Omnibus:              40.540       Durbin-Watson:          1.720
# Prob(Omnibus):        0.000        Jarque-Bera (JB):       96.645
# Skew:                 1.519        Prob(JB):               0.000
# Kurtosis:             6.737        Condition No.:          4
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.766
# Dependent Variable: y                AIC:                542.6043
# Date:               2017-05-21 10:06 BIC:                550.4198
# No. Observations:   100              Log-Likelihood:     -268.30
# Df Model:           2                F-statistic:        163.3
# Df Residuals:       97               Prob (F-statistic): 8.93e-32
# R-squared:          0.771            Scale:              12.918
# -------------------------------------------------------------------
#          Coef.     Std.Err.      t      P>|t|     [0.025     0.975]
# -------------------------------------------------------------------
# const     5.3224     1.0391    5.1220   0.0000     3.2600    7.3849
# x1      -10.8589     1.6308   -6.6586   0.0000   -14.0956   -7.6222
# x2        5.8047     0.5390   10.7685   0.0000     4.7349    6.8746
# -----------------------------------------------------------------
# Omnibus:              8.243        Durbin-Watson:           1.902
# Prob(Omnibus):        0.016        Jarque-Bera (JB):        7.864
# Skew:                 0.619        Prob(JB):                0.020
# Kurtosis:             3.595        Condition No.:           23
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.989
# Dependent Variable: y                AIC:                235.0222
# Date:               2017-05-21 10:06 BIC:                245.4429
# No. Observations:   100              Log-Likelihood:     -113.51
# Df Model:           3                F-statistic:        3057.
# Df Residuals:       96               Prob (F-statistic): 4.26e-95
# R-squared:          0.990            Scale:              0.59047
# ------------------------------------------------------------------
#            Coef.    Std.Err.     t      P>|t|    [0.025    0.975]
# ------------------------------------------------------------------
# const      -3.3949    0.2947  -11.5189  0.0000   -3.9799   -2.8099
# x1         25.8544    0.8870   29.1474  0.0000   24.0937   27.6152
# x2        -25.4069    0.7029  -36.1452  0.0000  -26.8022  -24.0117
# x3          7.0375    0.1563   45.0124  0.0000    6.7271    7.3478
# -----------------------------------------------------------------
# Omnibus:              6.325        Durbin-Watson:           1.534
# Prob(Omnibus):        0.042        Jarque-Bera (JB):        5.733
# Skew:                 0.548        Prob(JB):                0.057
# Kurtosis:             3.419        Condition No.:           158
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -46.9149
# Date:               2017-05-21 10:06 BIC:                -33.8890
# No. Observations:   100              Log-Likelihood:     28.457
# Df Model:           4                F-statistic:        3.919e+04
# Df Residuals:       95               Prob (F-statistic): 6.91e-152
# R-squared:          0.999            Scale:              0.034884
# --------------------------------------------------------------------
#            Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     -1.1450     0.0919   -12.4634   0.0000   -1.3274   -0.9626
# x1        10.8318     0.4404    24.5930   0.0000    9.9574   11.7062
# x2        -3.0243     0.5972    -5.0642   0.0000   -4.2099   -1.8387
# x3        -4.5475     0.2986   -15.2290   0.0000   -5.1403   -3.9547
# x4         1.9336     0.0494    39.1149   0.0000    1.8355    2.0318
# ------------------------------------------------------------------
# Omnibus:              1.503         Durbin-Watson:           2.041
# Prob(Omnibus):        0.472         Jarque-Bera (JB):        0.977
# Skew:                 -0.092        Prob(JB):                0.614
# Kurtosis:             3.448         Condition No.:           1159
# ==================================================================
# * The condition number is large (1e+03). This might indicate
# strong multicollinearity or other numerical problems.
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -46.8547
# Date:               2017-05-21 10:06 BIC:                -31.2236
# No. Observations:   100              Log-Likelihood:     29.427
# Df Model:           5                F-statistic:        3.163e+04
# Df Residuals:       94               Prob (F-statistic): 5.86e-150
# R-squared:          0.999            Scale:              0.034578
# --------------------------------------------------------------------
#            Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     -1.2339     0.1125   -10.9670   0.0000   -1.4573   -1.0105
# x1        11.6845     0.7663    15.2485   0.0000   10.1630   13.2059
# x2        -4.9936     1.5684    -3.1839   0.0020   -8.1076   -1.8795
# x3        -2.8021     1.3202    -2.1225   0.0364   -5.4234   -0.1808
# x4         1.2794     0.4846     2.6401   0.0097    0.3172    2.2417
# x5         0.0873     0.0643     1.3569   0.1781   -0.0404    0.2150
# ------------------------------------------------------------------
# Omnibus:              0.739         Durbin-Watson:           2.072
# Prob(Omnibus):        0.691         Jarque-Bera (JB):        0.319
# Skew:                 -0.064        Prob(JB):                0.853
# Kurtosis:             3.246         Condition No.:           8682
# ==================================================================
# * The condition number is large (9e+03). This might indicate
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Zadanie
# Analogiczne wyniki możemy izusklać za pomocą prostego kodu.

# %%
import statsmodels.formula.api as smf
# Turn the data into a pandas DataFrame, so that we
# can address them in the formulas with their name
df = pd.DataFrame({'x':x, 'y':y})

# Fit the models, and show the results
Res1F = smf.ols('y~x', df).fit()
Res2F = smf.ols('y ~ x+I(x**2)', df).fit()

# %%
print(Res1F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2F.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.487
# Model:                            OLS   Adj. R-squared:                  0.482
# Method:                 Least Squares   F-statistic:                     93.14
# Date:                Sun, 07 May 2017   Prob (F-statistic):           6.93e-16
# Time:                        09:57:02   Log-Likelihood:                -303.57
# No. Observations:                 100   AIC:                             611.1
# Df Residuals:                      98   BIC:                             616.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -2.6934      1.009     -2.669      0.009        -4.696    -0.691
# x              6.0015      0.622      9.651      0.000         4.767     7.236
# ==============================================================================
# Omnibus:                       38.537   Durbin-Watson:                   2.247
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               95.249
# Skew:                           1.413   Prob(JB):                     2.07e-21
# Kurtosis:                       6.857   Cond. No.                         4.20
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.763
# Model:                            OLS   Adj. R-squared:                  0.758
# Method:                 Least Squares   F-statistic:                     156.2
# Date:                Sun, 07 May 2017   Prob (F-statistic):           4.72e-31
# Time:                        09:57:02   Log-Likelihood:                -264.98
# No. Observations:                 100   AIC:                             536.0
# Df Residuals:                      97   BIC:                             543.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      5.6426      1.045      5.402      0.000         3.569     7.716
# x            -10.5600      1.616     -6.535      0.000       -13.767    -7.353
# I(x ** 2)      5.6480      0.532     10.623      0.000         4.593     6.703
# ==============================================================================
# Omnibus:                        5.962   Durbin-Watson:                   2.070
# Prob(Omnibus):                  0.051   Jarque-Bera (JB):                5.995
# Skew:                           0.390   Prob(JB):                       0.0499
# Kurtosis:                       3.911   Cond. No.                         22.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
