# %% [markdown]
# # Rozkład Rozkład t-Studenta  z $n$ stopniami swobody
# Rozkład Rozkład t-Studenta  z $n$ stopniami swobody ma gęstość
#
# $$
# f_{X}(x) = {\displaystyle {\frac {\Gamma ({\frac {n +1}{2}})}{{\sqrt {n \pi }}\,\Gamma ({\frac {n }{2}})}}\left(1+{\frac {x^{2}}{n }}\right)^{-({\frac {n +1}{2}})}\!},
# $$
#
# gdzie $\Gamma$ oznacza funkcję Gamma.
# \url{https://pl.wikipedia.org/wiki/Funkcja_\%CE\%93}

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

# %% [markdown]
# # Definiujemy zmienną losową

# %%
t = np.arange(-5, 5, 0.05)
n=4
X=stats.t(n)

# %% [markdown]
# # Narysujmy gętość zmiennej losowej

# %%
fig, ax = plt.subplots(1, 1)
plt.plot(t, X.pdf(t), '--', ms=8, label='frozen pdf')
plt.show()

# %% [markdown]
# # Narysujmy dystrybuantę zmiennej losowej

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(t, X.cdf(t), '--', ms=8, label='bernoulli cdf')
plt.show()

# %% [markdown]
# # Wylosujmy próbkę i narysujmy histogram na jednym obrazku

# %% [markdown]
# # Narysuj gęstości rozkładu jednostajnego z różnymi parametrami

# %% [markdown]
# # Narysuj kilka histogramów różnych próbek z roskładu jednostajnego o tych samych parametrach.
